# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Importing The Necessary Libraries like : numpy, pandas, matplotlib, seaborn

# %%
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from os import dup

# %% [markdown]
# # Uploading The DataSet

# %%
df = pd.read_csv('/content/heart_disease_health_indicators_BRFSS2015 2 (1).csv')

# %%
df
# Out:
#         HeartDiseaseorAttack  HighBP  HighChol  CholCheck  BMI  Smoker  \
# 0                          0       1         1          1   40       1
# 1                          0       0         0          0   25       1
# 2                          0       1         1          1   28       0
# 3                          0       1         0          1   27       0
# 4                          0       1         1          1   24       0
# ...                      ...     ...       ...        ...  ...     ...
# 253675                     0       1         1          1   45       0
# 253676                     0       1         1          1   18       0
# 253677                     0       0         0          1   28       0
# 253678                     0       1         0          1   23       0
# 253679                     1       1         1          1   25       0
#
#         Stroke  Diabetes  PhysActivity  Fruits  ...  AnyHealthcare  \
# 0            0         0             0       0  ...              1
# 1            0         0             1       0  ...              0
# 2            0         0             0       1  ...              1
# 3            0         0             1       1  ...              1
# 4            0         0             1       1  ...              1
# ...        ...       ...           ...     ...  ...            ...
# 253675       0         0             0       1  ...              1
# 253676       0         2             0       0  ...              1
# 253677       0         0             1       1  ...              1
# 253678       0         0             0       1  ...              1
# 253679       0         2             1       1  ...              1
#
#         NoDocbcCost  GenHlth  MentHlth  PhysHlth  DiffWalk  Sex  Age  \
# 0                 0        5        18        15         1    0    9
# 1                 1        3         0         0         0    0    7
# 2                 1        5        30        30         1    0    9
# 3                 0        2         0         0         0    0   11
# 4                 0        2         3         0         0    0   11
# ...             ...      ...       ...       ...       ...  ...  ...
# 253675            0        3         0         5         0    1    5
# 253676            0        4         0         0         1    0   11
# 253677            0        1         0         0         0    0    2
# 253678            0        3         0         0         0    1    7
# 253679            0        2         0         0         0    0    9
#
#         Education  Income
# 0               4       3
# 1               6       1
# 2               4       8
# 3               3       6
# 4               5       4
# ...           ...     ...
# 253675          6       7
# 253676          2       4
# 253677          5       2
# 253678          5       1
# 253679          6       2
#
# [253680 rows x 22 columns]

# %% [markdown]
# # Cleaning The DataSet

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# HeartDiseaseorAttack    0
# HighBP                  0
# HighChol                0
# CholCheck               0
# BMI                     0
# Smoker                  0
# Stroke                  0
# Diabetes                0
# PhysActivity            0
# Fruits                  0
# Veggies                 0
# HvyAlcoholConsump       0
# AnyHealthcare           0
# NoDocbcCost             0
# GenHlth                 0
# MentHlth                0
# PhysHlth                0
# DiffWalk                0
# Sex                     0
# Age                     0
# Education               0
# Income                  0
# dtype: int64

# %%
df_clean = df.dropna()
df_clean
# Out:
#         HeartDiseaseorAttack  HighBP  HighChol  CholCheck  BMI  Smoker  \
# 0                          0       1         1          1   40       1
# 1                          0       0         0          0   25       1
# 2                          0       1         1          1   28       0
# 3                          0       1         0          1   27       0
# 4                          0       1         1          1   24       0
# ...                      ...     ...       ...        ...  ...     ...
# 253675                     0       1         1          1   45       0
# 253676                     0       1         1          1   18       0
# 253677                     0       0         0          1   28       0
# 253678                     0       1         0          1   23       0
# 253679                     1       1         1          1   25       0
#
#         Stroke  Diabetes  PhysActivity  Fruits  ...  AnyHealthcare  \
# 0            0         0             0       0  ...              1
# 1            0         0             1       0  ...              0
# 2            0         0             0       1  ...              1
# 3            0         0             1       1  ...              1
# 4            0         0             1       1  ...              1
# ...        ...       ...           ...     ...  ...            ...
# 253675       0         0             0       1  ...              1
# 253676       0         2             0       0  ...              1
# 253677       0         0             1       1  ...              1
# 253678       0         0             0       1  ...              1
# 253679       0         2             1       1  ...              1
#
#         NoDocbcCost  GenHlth  MentHlth  PhysHlth  DiffWalk  Sex  Age  \
# 0                 0        5        18        15         1    0    9
# 1                 1        3         0         0         0    0    7
# 2                 1        5        30        30         1    0    9
# 3                 0        2         0         0         0    0   11
# 4                 0        2         3         0         0    0   11
# ...             ...      ...       ...       ...       ...  ...  ...
# 253675            0        3         0         5         0    1    5
# 253676            0        4         0         0         1    0   11
# 253677            0        1         0         0         0    0    2
# 253678            0        3         0         0         0    1    7
# 253679            0        2         0         0         0    0    9
#
#         Education  Income
# 0               4       3
# 1               6       1
# 2               4       8
# 3               3       6
# 4               5       4
# ...           ...     ...
# 253675          6       7
# 253676          2       4
# 253677          5       2
# 253678          5       1
# 253679          6       2
#
# [253680 rows x 22 columns]

# %%
dupli_rows = df_clean.duplicated().sum()
dupli_rows
# Out:
# 23899

# %%
df_clean = df_clean.drop_duplicates()
df_clean
# Out:
#         HeartDiseaseorAttack  HighBP  HighChol  CholCheck  BMI  Smoker  \
# 0                          0       1         1          1   40       1
# 1                          0       0         0          0   25       1
# 2                          0       1         1          1   28       0
# 3                          0       1         0          1   27       0
# 4                          0       1         1          1   24       0
# ...                      ...     ...       ...        ...  ...     ...
# 253675                     0       1         1          1   45       0
# 253676                     0       1         1          1   18       0
# 253677                     0       0         0          1   28       0
# 253678                     0       1         0          1   23       0
# 253679                     1       1         1          1   25       0
#
#         Stroke  Diabetes  PhysActivity  Fruits  ...  AnyHealthcare  \
# 0            0         0             0       0  ...              1
# 1            0         0             1       0  ...              0
# 2            0         0             0       1  ...              1
# 3            0         0             1       1  ...              1
# 4            0         0             1       1  ...              1
# ...        ...       ...           ...     ...  ...            ...
# 253675       0         0             0       1  ...              1
# 253676       0         2             0       0  ...              1
# 253677       0         0             1       1  ...              1
# 253678       0         0             0       1  ...              1
# 253679       0         2             1       1  ...              1
#
#         NoDocbcCost  GenHlth  MentHlth  PhysHlth  DiffWalk  Sex  Age  \
# 0                 0        5        18        15         1    0    9
# 1                 1        3         0         0         0    0    7
# 2                 1        5        30        30         1    0    9
# 3                 0        2         0         0         0    0   11
# 4                 0        2         3         0         0    0   11
# ...             ...      ...       ...       ...       ...  ...  ...
# 253675            0        3         0         5         0    1    5
# 253676            0        4         0         0         1    0   11
# 253677            0        1         0         0         0    0    2
# 253678            0        3         0         0         0    1    7
# 253679            0        2         0         0         0    0    9
#
#         Education  Income
# 0               4       3
# 1               6       1
# 2               4       8
# 3               3       6
# 4               5       4
# ...           ...     ...
# 253675          6       7
# 253676          2       4
# 253677          5       2
# 253678          5       1
# 253679          6       2
#
# [229781 rows x 22 columns]

# %%
df_clean.dtypes
# Out:
# HeartDiseaseorAttack    int64
# HighBP                  int64
# HighChol                int64
# CholCheck               int64
# BMI                     int64
# Smoker                  int64
# Stroke                  int64
# Diabetes                int64
# PhysActivity            int64
# Fruits                  int64
# Veggies                 int64
# HvyAlcoholConsump       int64
# AnyHealthcare           int64
# NoDocbcCost             int64
# GenHlth                 int64
# MentHlth                int64
# PhysHlth                int64
# DiffWalk                int64
# Sex                     int64
# Age                     int64
# Education               int64
# Income                  int64
# dtype: object

# %% [markdown]
# # * Univariate Analysis

# %% [markdown]
# # a) Examine Distributions of Individual Variables:
#  -> Plot histograms or bar charts to visualize the distribution of key variables such as age, BMI, mental health days (Menthlth), and physical health days (PhysHlth).

# %% [markdown]
# # Histogram for PhysHlth

# %%
plt.hist(df_clean['PhysHlth'], color='purple', edgecolor='blue', cumulative=-1)
# Out:
# (array([229781.,  67335.,  46782.,  40114.,  34287.,  31057.,  25935.,
#          22488.,  21699.,  20222.]),
#  array([ 0.,  3.,  6.,  9., 12., 15., 18., 21., 24., 27., 30.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Histogram for BMI

# %%
plt.hist(df_clean['BMI'], color='blue',edgecolor='white', cumulative=-1)
# Out:
# (array([2.29781e+05, 2.17577e+05, 8.49420e+04, 1.99880e+04, 4.06900e+03,
#         1.35700e+03, 6.93000e+02, 5.21000e+02, 2.79000e+02, 5.40000e+01]),
#  array([12. , 20.6, 29.2, 37.8, 46.4, 55. , 63.6, 72.2, 80.8, 89.4, 98. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Histogram for MentHlth

# %%
plt.hist(df_clean['MentHlth'], color='orange', edgecolor='green', cumulative=-1)
# Out:
# (array([229781.,  56152.,  36163.,  31446.,  24962.,  23356.,  17713.,
#          14238.,  13910.,  12644.]),
#  array([ 0.,  3.,  6.,  9., 12., 15., 18., 21., 24., 27., 30.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Histogram for Age

# %%
plt.hist(df_clean['Age'], color='green', edgecolor='white', cumulative=-1)
# Out:
# (array([229781., 217201., 207176., 194942., 180892., 163593., 113152.,
#          83416.,  54248.,  32207.]),
#  array([ 1. ,  2.2,  3.4,  4.6,  5.8,  7. ,  8.2,  9.4, 10.6, 11.8, 13. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # b. Investigate Prevalence of Health Conditions:
# --> Plot bar charts or pie charts to show the prevalence of high blood pressure (HighBP), high cholesterol (HighChol), and other health conditions.

# %% [markdown]
# # Piechart for HighChol

# %%
df_clean.groupby('HighChol').size().plot(kind = 'pie', autopct = '%1.1f%%', labels=['Female', 'Male'])
# Out:
# <Axes: >

# %% [markdown]
# # Piechart for HighBP

# %%
df_clean.groupby('HighBP').size().plot(kind = 'pie', autopct = '%1.1f%%', labels=['Female', 'Male'])
# Out:
# <Axes: >

# %% [markdown]
# # Piechart for GenHlth

# %%
df_clean.groupby('GenHlth').size().plot(kind = 'pie', autopct = '%1.1f%%').legend().set_title('GenHlth')

# %% [markdown]
# # c. Analyze Distribution of Heart Disease (Target Variable):
#  --> Visualize the distribution of heart disease cases using a bar chart or pie chart.

# %%
heart_disease_counts = df_clean['HeartDiseaseorAttack'].value_counts()
colors = ['blue', 'red']
plt.figure(figsize=(6, 4))
sns.barplot(x=heart_disease_counts.index, y=heart_disease_counts.values, palette=colors)
plt.xlabel('Heart Disease or Attack')
plt.ylabel('Count')
plt.title('Distribution of Heart Disease Cases')
plt.xticks(range(len(heart_disease_counts.index)), ['No Disease', 'Disease'])
plt.show()
# Out:
# <ipython-input-17-d3597184af08>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=heart_disease_counts.index, y=heart_disease_counts.values, palette=colors)

# %% [markdown]
# # * Bivariate Analysis

# %% [markdown]
# # a. Explore Relationships with Heart Disease:
# --> Compare the distribution of key variables (e.g., HighBP, HighChol, BMI) between individuals with and without heart disease.

# %% [markdown]
# # BMI

# %%
sns.distplot(df_clean[df_clean['HeartDiseaseorAttack']==0] ['BMI'], color='blue', hist=False)
sns.distplot(df_clean[df_clean['HeartDiseaseorAttack']==1] ['BMI'], color='red', hist=False)
# Out:
# <ipython-input-18-1958b1147872>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_clean[df_clean['HeartDiseaseorAttack']==0] ['BMI'], color='blue', hist=False)
# <ipython-input-18-1958b1147872>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_clean[df_clean['HeartDiseaseorAttack']==1] ['BMI'], color='red', hist=False)
# <Axes: xlabel='BMI', ylabel='Density'>

# %% [markdown]
# # HighChol

# %%
sns.distplot(df_clean[df_clean['HeartDiseaseorAttack']==0] ['HighChol'], color='blue', hist=False)
sns.distplot(df_clean[df_clean['HeartDiseaseorAttack']==1] ['HighChol'], color='orange', hist=False)
# Out:
# <ipython-input-19-0c149e484079>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_clean[df_clean['HeartDiseaseorAttack']==0] ['HighChol'], color='blue', hist=False)
# <ipython-input-19-0c149e484079>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_clean[df_clean['HeartDiseaseorAttack']==1] ['HighChol'], color='orange', hist=False)
# <Axes: xlabel='HighChol', ylabel='Density'>

# %% [markdown]
# # HighBP

# %%
sns.distplot(df_clean[df_clean['HeartDiseaseorAttack']==0] ['HighBP'], color='green', hist=False).legend()
sns.distplot(df_clean[df_clean['HeartDiseaseorAttack']==1] ['HighBP'], color='orange', hist=False).legend()
# Out:
# <ipython-input-20-a40720739b69>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_clean[df_clean['HeartDiseaseorAttack']==0] ['HighBP'], color='green', hist=False).legend()
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# <ipython-input-20-a40720739b69>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_clean[df_clean['HeartDiseaseorAttack']==1] ['HighBP'], color='orange', hist=False).legend()
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # b. Visualize Correlations Between Variables:
# --> Use scatter plots or correlation matrices to explore relationships between continuous variables.

# %%
corr = df_clean[['BMI', 'MentHlth', 'PhysHlth', 'Age']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # c. Compare Heart Disease Across Demographic Groups:
# --> Analyze the prevalence of heart disease across different demographic groups (e.g., age, gender, education) using bar charts or pivot tables.

# %% [markdown]
# # For Age

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Age', y='HeartDiseaseorAttack', data=df_clean, palette='viridis')
plt.title('Heart Disease Prevalence Across Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Prevalence of Heart Disease')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-22-6a193707fd4a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Age', y='HeartDiseaseorAttack', data=df_clean, palette='viridis')

# %% [markdown]
# # For Sex

# %%
plt.figure(figsize=(10, 6))
color = ['blue', 'green']
sns.barplot(x='Sex', y='HeartDiseaseorAttack', data=df_clean, palette=color)
plt.title('Heart Disease Prevalence Across Sex Groups')
plt.xlabel('Sex')
plt.ylabel('Prevalence of Heart Disease')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-23-077f3bd8b37d>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Sex', y='HeartDiseaseorAttack', data=df_clean, palette=color)

# %% [markdown]
# # For Education

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Education', y='HeartDiseaseorAttack', data=df_clean, palette='rocket')
plt.title('Heart Disease Prevalence Across Education')
plt.xlabel('Education')
plt.ylabel('Prevalence of Heart Disease')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-24-7d8dd1860fdd>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Education', y='HeartDiseaseorAttack', data=df_clean, palette='rocket')
